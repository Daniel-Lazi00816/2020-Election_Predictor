# %% [markdown]
# # Problem Statement
# Can we predict voter turnout for Democratic primaries on March the 17th.
#
# **Goals and Objectives**
#
# 1) Use  Bayesian inference and MCMC with prior data gotten from the previous Democratic primary cycle methods to create posterior distributions.
#
# 2) Examine trends in current polling data available.
#
# 3) Should 2016 results have been reasonably well predicted with PVI score and voting results, use information to predict possible voting results for the 2020 general election
#
# **Success Metrics**
#
# 1)
#
# **Risks and Assumptions**
#
# 1) Insufficient data, for such small sample size are other methods of discerning voter turnoat than what I've proposed.
#
# **Proposed Methods and Models**
#
# 1)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.style as style
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
pres_polls = pd.read_csv('../Data/president_polls.csv')
primary_polls = pd.read_csv('../Data/dem_primary_polls.csv')
az = pd.read_csv('..//Data//2016_az.csv')
oh = pd.read_csv('..//Data//2016_ohio.csv')
fl = pd.read_csv('..//Data//2016_fl.csv')
ill = pd.read_csv('..//Data//2016_Ill.csv')

# %%
pres_polls.head(20)
# Out:
#     question_id  poll_id  cycle         state  pollster_id  \
# 0        119842    64774   2020      Michigan         1528
# 1        119842    64774   2020      Michigan         1528
# 2        119843    64774   2020      Michigan         1528
# 3        119843    64774   2020      Michigan         1528
# 4        119814    64766   2020      Michigan          568
# 5        119814    64766   2020      Michigan          568
# 6        119815    64766   2020      Michigan          568
# 7        119815    64766   2020      Michigan          568
# 8        119816    64767   2020  Pennsylvania          568
# 9        119816    64767   2020  Pennsylvania          568
# 10       119817    64767   2020  Pennsylvania          568
# 11       119817    64767   2020  Pennsylvania          568
# 12       119818    64768   2020     Wisconsin          568
# 13       119818    64768   2020     Wisconsin          568
# 14       119819    64768   2020     Wisconsin          568
# 15       119819    64768   2020     Wisconsin          568
# 16       119795    64760   2020           NaN          399
# 17       119795    64760   2020           NaN          399
# 18       119807    64764   2020      Michigan          320
# 19       119807    64764   2020      Michigan          320
#
#                                     pollster sponsor_ids    sponsors  \
# 0                                 AtlasIntel         NaN         NaN
# 1                                 AtlasIntel         NaN         NaN
# 2                                 AtlasIntel         NaN         NaN
# 3                                 AtlasIntel         NaN         NaN
# 4                                     YouGov        1213  Yahoo News
# 5                                     YouGov        1213  Yahoo News
# 6                                     YouGov        1213  Yahoo News
# 7                                     YouGov        1213  Yahoo News
# 8                                     YouGov        1213  Yahoo News
# 9                                     YouGov        1213  Yahoo News
# 10                                    YouGov        1213  Yahoo News
# 11                                    YouGov        1213  Yahoo News
# 12                                    YouGov        1213  Yahoo News
# 13                                    YouGov        1213  Yahoo News
# 14                                    YouGov        1213  Yahoo News
# 15                                    YouGov        1213  Yahoo News
# 16  Rasmussen Reports/Pulse Opinion Research         NaN         NaN
# 17  Rasmussen Reports/Pulse Opinion Research         NaN         NaN
# 18                       Monmouth University         NaN         NaN
# 19                       Monmouth University         NaN         NaN
#
#                                 display_name  pollster_rating_id  \
# 0                                 AtlasIntel                 546
# 1                                 AtlasIntel                 546
# 2                                 AtlasIntel                 546
# 3                                 AtlasIntel                 546
# 4                                     YouGov                 391
# 5                                     YouGov                 391
# 6                                     YouGov                 391
# 7                                     YouGov                 391
# 8                                     YouGov                 391
# 9                                     YouGov                 391
# 10                                    YouGov                 391
# 11                                    YouGov                 391
# 12                                    YouGov                 391
# 13                                    YouGov                 391
# 14                                    YouGov                 391
# 15                                    YouGov                 391
# 16  Rasmussen Reports/Pulse Opinion Research                 277
# 17  Rasmussen Reports/Pulse Opinion Research                 277
# 18                       Monmouth University                 215
# 19                       Monmouth University                 215
#
#                         pollster_rating_name fte_grade  sample_size  \
# 0                                 AtlasIntel       NaN       1100.0
# 1                                 AtlasIntel       NaN       1100.0
# 2                                 AtlasIntel       NaN       1100.0
# 3                                 AtlasIntel       NaN       1100.0
# 4                                     YouGov        B-        566.0
# 5                                     YouGov        B-        566.0
# 6                                     YouGov        B-        566.0
# 7                                     YouGov        B-        566.0
# 8                                     YouGov        B-        725.0
# 9                                     YouGov        B-        725.0
# 10                                    YouGov        B-        725.0
# 11                                    YouGov        B-        725.0
# 12                                    YouGov        B-        459.0
# 13                                    YouGov        B-        459.0
# 14                                    YouGov        B-        459.0
# 15                                    YouGov        B-        459.0
# 16  Rasmussen Reports/Pulse Opinion Research        C+       1000.0
# 17  Rasmussen Reports/Pulse Opinion Research        C+       1000.0
# 18                       Monmouth University        A+        977.0
# 19                       Monmouth University        A+        977.0
#
#    population population_full methodology     office_type  seat_number  \
# 0          rv              rv      Online  U.S. President            0
# 1          rv              rv      Online  U.S. President            0
# 2          rv              rv      Online  U.S. President            0
# 3          rv              rv      Online  U.S. President            0
# 4          rv              rv      Online  U.S. President            0
# 5          rv              rv      Online  U.S. President            0
# 6          rv              rv      Online  U.S. President            0
# 7          rv              rv      Online  U.S. President            0
# 8          rv              rv      Online  U.S. President            0
# 9          rv              rv      Online  U.S. President            0
# 10         rv              rv      Online  U.S. President            0
# 11         rv              rv      Online  U.S. President            0
# 12         rv              rv      Online  U.S. President            0
# 13         rv              rv      Online  U.S. President            0
# 14         rv              rv      Online  U.S. President            0
# 15         rv              rv      Online  U.S. President            0
# 16         lv              lv  IVR/Online  U.S. President            0
# 17         lv              lv  IVR/Online  U.S. President            0
# 18         rv              rv  Live Phone  U.S. President            0
# 19         rv              rv  Live Phone  U.S. President            0
#
#     seat_name start_date end_date election_date sponsor_candidate  internal  \
# 0         NaN     3/7/20   3/9/20           NaN               NaN     False
# 1         NaN     3/7/20   3/9/20           NaN               NaN     False
# 2         NaN     3/7/20   3/9/20           NaN               NaN     False
# 3         NaN     3/7/20   3/9/20           NaN               NaN     False
# 4         NaN     3/6/20   3/8/20           NaN               NaN     False
# 5         NaN     3/6/20   3/8/20           NaN               NaN     False
# 6         NaN     3/6/20   3/8/20           NaN               NaN     False
# 7         NaN     3/6/20   3/8/20           NaN               NaN     False
# 8         NaN     3/6/20   3/8/20           NaN               NaN     False
# 9         NaN     3/6/20   3/8/20           NaN               NaN     False
# 10        NaN     3/6/20   3/8/20           NaN               NaN     False
# 11        NaN     3/6/20   3/8/20           NaN               NaN     False
# 12        NaN     3/6/20   3/8/20           NaN               NaN     False
# 13        NaN     3/6/20   3/8/20           NaN               NaN     False
# 14        NaN     3/6/20   3/8/20           NaN               NaN     False
# 15        NaN     3/6/20   3/8/20           NaN               NaN     False
# 16        NaN     3/5/20   3/8/20           NaN               NaN     False
# 17        NaN     3/5/20   3/8/20           NaN               NaN     False
# 18        NaN     3/5/20   3/8/20           NaN               NaN     False
# 19        NaN     3/5/20   3/8/20           NaN               NaN     False
#
#    partisan  tracking  nationwide_batch  ranked_choice_reallocated  \
# 0       NaN       NaN             False                      False
# 1       NaN       NaN             False                      False
# 2       NaN       NaN             False                      False
# 3       NaN       NaN             False                      False
# 4       NaN       NaN             False                      False
# 5       NaN       NaN             False                      False
# 6       NaN       NaN             False                      False
# 7       NaN       NaN             False                      False
# 8       NaN       NaN             False                      False
# 9       NaN       NaN             False                      False
# 10      NaN       NaN             False                      False
# 11      NaN       NaN             False                      False
# 12      NaN       NaN             False                      False
# 13      NaN       NaN             False                      False
# 14      NaN       NaN             False                      False
# 15      NaN       NaN             False                      False
# 16      NaN       NaN             False                      False
# 17      NaN       NaN             False                      False
# 18      NaN       NaN             False                      False
# 19      NaN       NaN             False                      False
#
#       created_at notes                                                url  \
# 0   3/9/20 22:41   NaN  https://projects.fivethirtyeight.com/polls/202...
# 1   3/9/20 22:41   NaN  https://projects.fivethirtyeight.com/polls/202...
# 2   3/9/20 22:41   NaN  https://projects.fivethirtyeight.com/polls/202...
# 3   3/9/20 22:41   NaN  https://projects.fivethirtyeight.com/polls/202...
# 4   3/9/20 14:12   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 5   3/9/20 14:12   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 6   3/9/20 14:12   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 7   3/9/20 14:12   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 8   3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 9   3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 10  3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 11  3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 12  3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 13  3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 14  3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 15  3/9/20 14:13   NaN  https://docs.cdn.yougov.com/fwvdnnbigm/2020030...
# 16  3/9/20 10:30   NaN  https://www.rasmussenreports.com/public_conten...
# 17  3/9/20 10:30   NaN  https://www.rasmussenreports.com/public_conten...
# 18  3/9/20 13:05   NaN  https://www.monmouth.edu/polling-institute/doc...
# 19  3/9/20 13:05   NaN  https://www.monmouth.edu/polling-institute/doc...
#
#       stage   answer       candidate_name candidate_party   pct
# 0   general  Sanders      Bernard Sanders             DEM  45.5
# 1   general    Trump         Donald Trump             REP  43.4
# 2   general    Biden  Joseph R. Biden Jr.             DEM  44.1
# 3   general    Trump         Donald Trump             REP  45.5
# 4   general    Biden  Joseph R. Biden Jr.             DEM  45.0
# 5   general    Trump         Donald Trump             REP  41.0
# 6   general  Sanders      Bernard Sanders             DEM  43.0
# 7   general    Trump         Donald Trump             REP  42.0
# 8   general    Biden  Joseph R. Biden Jr.             DEM  46.0
# 9   general    Trump         Donald Trump             REP  40.0
# 10  general  Sanders      Bernard Sanders             DEM  43.0
# 11  general    Trump         Donald Trump             REP  41.0
# 12  general    Biden  Joseph R. Biden Jr.             DEM  44.0
# 13  general    Trump         Donald Trump             REP  42.0
# 14  general  Sanders      Bernard Sanders             DEM  46.0
# 15  general    Trump         Donald Trump             REP  40.0
# 16  general    Biden  Joseph R. Biden Jr.             DEM  48.0
# 17  general    Trump         Donald Trump             REP  42.0
# 18  general  Sanders      Bernard Sanders             DEM  46.0
# 19  general    Trump         Donald Trump             REP  41.0

# %% [markdown]
# # Presidential Data EDA

# %%
candidates = ['Biden', 'Sanders', 'Trump']
pres_polls = pres_polls[pres_polls.answer.isin(candidates)]
pres_polls['answer'].value_counts()
# Out:
# Trump      1837
# Biden       402
# Sanders     375
# Name: answer, dtype: int64

# %%
pres_polls.stage.value_counts()
# Out:
# general    2614
# Name: stage, dtype: int64

# %%
#Switch all date columns to date time columns. 
pres_polls['start_date'] = pres_polls['start_date'].astype('datetime64[ns]')
pres_polls['end_date'] = pres_polls['end_date'].astype('datetime64[ns]')

# %%
polling_frequency = pres_polls['state'].value_counts()
polling_frequency.plot.bar(figsize = (20,10))
plt.xlabel('States', fontsize=15)
plt.ylabel('Polls Conducted', fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('538 Presidential Polls By State', fontsize=20);
#So up to this point we see a vast seperation in polling between states
#I wouldn't say the correlation of polling to a state being a tossup is one but certainly we expect
#States which we know the presidential outcome, i.e Arkansas, to have a few amount of polls conducted 
#Versus a state like New Hampshire which does have a chance to flip on election night

# %%
#Ok let's now look at our democratic candidates seperately
polls_sanders = pres_polls[pres_polls['answer']=='Sanders']
polls_biden = pres_polls[pres_polls['answer']=='Biden']

# %%
# I want to show change over time in polling averages for each candidate in a specific state
# The state's will examine are classical "swing" states, Pennsylvania, Ohio, Michigan, Wisconsin, 
# North Carolina, New Hampshire, Iowa and Florida 

#Pennsylvania
biden_pa = polls_biden.loc[polls_biden['state'] == 'Pennsylvania', ['pct', 'start_date']]
biden_pa.set_index(['start_date'], inplace=True)
sanders_pa = polls_sanders.loc[polls_sanders['state']== 'Pennsylvania', ['pct', 'start_date']]
sanders_pa.set_index(['start_date'], inplace=True)

#Ohio
biden_oh = polls_biden.loc[polls_biden['state']=='Ohio', ['pct', 'start_date']]
biden_oh.set_index(['start_date'], inplace=True)
sanders_oh = polls_sanders.loc[polls_sanders['state']== 'Ohio', ['pct', 'start_date']]
sanders_oh.set_index(['start_date'], inplace=True)

#Michigan
biden_mi = polls_biden.loc[polls_biden['state'] == 'Michigan', ['pct', 'start_date']]
biden_mi.set_index(['start_date'], inplace=True)
sanders_mi = polls_sanders.loc[polls_sanders['state']== 'Michigan', ['pct', 'start_date']]
sanders_mi.set_index(['start_date'], inplace=True)

#Wisconsin
biden_wi = polls_biden.loc[polls_biden['state'] == 'Wisconsin', ['pct', 'start_date']]
biden_wi.set_index(['start_date'], inplace=True)
sanders_wi = polls_sanders.loc[polls_sanders['state']== 'Wisconsin', ['pct', 'start_date']]
sanders_wi.set_index(['start_date'], inplace=True)

#North Carolina 
biden_nc = polls_biden.loc[polls_biden['state'] == 'North Carolina', ['pct', 'start_date']]
biden_nc.set_index(['start_date'], inplace=True)
sanders_nc = polls_sanders.loc[polls_sanders['state']== 'North Carolina', ['pct', 'start_date']]
sanders_nc.set_index(['start_date'], inplace=True)

#New Hampshire
biden_nh = polls_biden.loc[polls_biden['state'] == 'New Hampshire', ['pct', 'start_date']]
biden_nh.set_index(['start_date'], inplace=True)
sanders_nh = polls_sanders.loc[polls_sanders['state']== 'New Hampshire', ['pct', 'start_date']]
sanders_nh.set_index(['start_date'], inplace=True)

#Iowa
biden_ia = polls_biden.loc[polls_biden['state'] == 'Iowa', ['pct', 'start_date']]
biden_ia.set_index(['start_date'], inplace=True)
sanders_ia = polls_sanders.loc[polls_sanders['state']== 'Iowa', ['pct', 'start_date']]
sanders_ia.set_index(['start_date'], inplace=True)

#Florida
biden_fl = polls_biden.loc[polls_biden['state'] == 'Florida', ['pct', 'start_date']]
biden_fl.set_index(['start_date'], inplace=True)
sanders_fl = polls_sanders.loc[polls_sanders['state']== 'Florida', ['pct', 'start_date']]
sanders_fl.set_index(['start_date'], inplace=True)

# %%
style.use('fivethirtyeight')
plt.title('Pennsylvania')
plt.plot(biden_pa.index.values, biden_pa['pct'], label='Biden')
plt.plot(sanders_pa.index.values, sanders_pa['pct'], label='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Ohio')
plt.plot(biden_oh.index.values, biden_oh['pct'], label='Biden')
plt.plot(sanders_oh.index.values, sanders_oh['pct'], label='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Michigan')
plt.plot(biden_mi.index.values, biden_mi['pct'], label ='Biden')
plt.plot(sanders_mi.index.values, sanders_mi['pct'], label ='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Wisconsin')
plt.plot(biden_wi.index.values, biden_wi['pct'], label = 'Biden')
plt.plot(sanders_wi.index.values, sanders_wi['pct'], label ='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('North Carolina')
plt.plot(biden_nc.index.values, biden_nc['pct'], label = 'Biden')
plt.plot(sanders_nc.index.values, sanders_nc['pct'], label = 'Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('New Hampshire')
plt.plot(biden_nh.index.values, biden_nh['pct'], label = 'Biden')
plt.plot(sanders_nh.index.values, sanders_nh['pct'], label = 'Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Iowa')
plt.plot(biden_ia.index.values, biden_ia['pct'], label = 'Biden')
plt.plot(sanders_ia.index.values, sanders_ia['pct'], label = 'Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Florida')
plt.legend((biden_fl['pct'], sanders_fl['pct']), ('Biden', 'Sanders'))
plt.plot(biden_fl.index.values, biden_fl['pct'], label = 'Biden')
plt.plot(sanders_fl.index.values, sanders_fl['pct'], label = 'Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Primary Data EDA
# **Arizona - Semi Closed Primary**
#
# A previously unaffiliated voter can participate in the primary of his or her choice. A voter who who previously affiliated with a political party can only vote in that party's primary.

# %%
rm_comma = lambda x: x.replace(',', '')
az['Clinton Votes'] = az['Clinton Votes'].map(rm_comma).astype(int)
az['Sanders Votes'] = az['Sanders Votes'].map(rm_comma).astype(int)
az.dtypes
# Out:
# County           object
# Clinton Votes     int64
# Sanders Votes     int64
# dtype: object

# %%
n_groups = 13
votes_clinton = az.drop(labels = [7, 10], axis = 'index')['Clinton Votes']
votes_sanders = az.drop(labels = [7, 10], axis = 'index')['Sanders Votes']

# create plot
fig, ax = plt.subplots(figsize=(20,12))
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, votes_clinton, bar_width,
                                        alpha=opacity,
                                        color='b',
                                        label='Clinton')

rects2 = plt.bar(index + bar_width, votes_sanders, bar_width,
                                                    alpha=opacity,
                                                    color='g',
                                                    label='Sanders')

plt.xlabel('Counties', fontsize=25)
plt.ylabel('Vote Total', fontsize=25)
plt.title('2016 Arizona Democratic Primary Results', fontsize=20)
plt.xticks(index + bar_width, az['County'], fontsize=20)
plt.yticks(fontsize=15)
plt.legend(fontsize=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Florida - Closed Primary State**

# %%
fl = fl[fl['PartyCode']=='DEM']
fl.drop(columns=['PartyCode', 'ElectionDate', 'RaceCode', 'RaceName', 'Precincts', 'PrecinctsReporting',
                'CanNameFirst', 'RaceName'], inplace=True)
fl.reset_index(inplace=True, drop=True)

# %%
sa_fl = fl.loc[fl['CanNameLast'] == 'Sanders']
sa_fl.reset_index(drop=True, inplace = True)
cl_fl = fl.loc[fl['CanNameLast'] == 'Clinton']
cl_fl.reset_index(drop=True, inplace=True)

# %%
#Ten Most populated counties in Florida
n_groups = 10

fl_votes_clinton = cl_fl.iloc[[4, 5, 12, 15, 28, 35, 47, 49, 51, 52], 4]
fl_votes_sanders = sa_fl.iloc[[4, 5, 12, 15, 28, 35, 47, 49, 51, 52], 4]
fl_ten_high_pop_county = fl.iloc[[4, 5, 12, 15, 28, 35, 47, 49, 51, 52], 2]

# create plot
fig, ax = plt.subplots(figsize=(20,12))
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, fl_votes_clinton, bar_width,
                                        alpha=opacity,
                                        color='b',
                                        label='Clinton')

rects2 = plt.bar(index + bar_width, fl_votes_sanders, bar_width,
                                                    alpha=opacity,
                                                    color='g',
                                                    label='Sanders')

plt.xlabel('Ten Most Populated Counties', fontsize=25)
plt.ylabel('Vote Total', fontsize=25)
plt.title('2016 Florida Democratic Primary Results', fontsize=30)
plt.xticks(index + bar_width, fl_ten_high_pop_county, fontsize=20)
plt.yticks(fontsize=15)
plt.legend(fontsize=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Illinois - Semi Closed Primary State**
#
# In Illinois, a voter states his or her affiliation with a political party at the polling place in order to vote in that party's primary. Because the voter does not have to register partisan affiliation in advance, Illinois' primaries are considered open.

# %%
ill = ill.drop(columns=['Clinton','Sanders'])
ill['Clinton Votes'] = ill['Clinton Votes'].map(rm_comma).astype(int)
ill['Sanders Votes'] = ill['Sanders Votes'].map(rm_comma).astype(int)
ill.dtypes
# Out:
# County           object
# Clinton Votes     int64
# Sanders Votes     int64
# dtype: object

# %%
#Ten Most populated counties in Illinois
n_groups = 10

ill_votes_clinton = ill.iloc[[9, 15, 21, 44, 48, 55, 59, 81, 98, 100], 1]
ill_votes_sanders = ill.iloc[[9, 15, 21, 44, 48, 55, 59, 81, 98, 100], 2]
ill_ten_high_pop_county = ill.iloc[[9, 15, 21, 44, 48, 55, 59, 81, 98, 100], 0]

# create plot
fig, ax = plt.subplots(figsize=(20,12))
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, ill_votes_clinton, bar_width,
                                        alpha=opacity,
                                        color='b',
                                        label='Clinton')

rects2 = plt.bar(index + bar_width, ill_votes_sanders, bar_width,
                                                    alpha=opacity,
                                                    color='g',
                                                    label='Sanders')

plt.xlabel('Ten Most Populated Counties', fontsize=25)
plt.ylabel('Vote Total', fontsize=25)
plt.title('2016 Illinois Democratic Primary Results', fontsize=30)
plt.xticks(index + bar_width, ill_ten_high_pop_county, fontsize=20)
plt.yticks(fontsize=15)
plt.legend(fontsize=30)

plt.tight_layout()
plt.show()

# %%
# Eleven through 20 of most populated counties in Illinois
n_groups = 10

ill2_votes_clinton = ill.iloc[[18, 45, 46, 49, 56, 57, 71, 80, 83, 89], 1]
ill2_votes_sanders = ill.iloc[[18, 45, 46, 49, 56, 57, 71, 80, 83, 89], 2]
ill2_ten_high_pop_county = ill.iloc[[18, 45, 46, 49, 56, 57, 71, 80, 83, 89], 0]

# create plot
fig, ax = plt.subplots(figsize=(20,12))
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, ill2_votes_clinton, bar_width,
                                        alpha=opacity,
                                        color='b',
                                        label='Clinton')

rects2 = plt.bar(index + bar_width, ill2_votes_sanders, bar_width,
                                                    alpha=opacity,
                                                    color='g',
                                                    label='Sanders')

plt.xlabel('Counties', fontsize=25)
plt.ylabel('Vote Total', fontsize=25)
plt.title('2016 Illinois Democratic Primary Results', fontsize=20)
plt.xticks(index + bar_width, ill2_ten_high_pop_county, fontsize=20)
plt.yticks(fontsize=15)
plt.legend(fontsize=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ohio - Open Primary**
#
# Ohio law provides for open primaries, meaning voters do not have to register with a party to participate in its primary. Voters select the ballot of the party whose primary they wish to vote in at the polling place.

# %%
oh = oh.drop(columns=['Clinton','Sanders'])
oh['Clinton Votes'] = oh['Clinton Votes'].map(rm_comma).astype(int)
oh['Sanders Votes'] = oh['Sanders Votes'].map(rm_comma).astype(int)
oh.dtypes
# Out:
# County           object
# Clinton Votes     int64
# Sanders Votes     int64
# dtype: object

# %%
#Ten least populated counties in Ohio 
n_groups = 10

oh_votes_clinton_b10 = oh.iloc[[9, 33, 34, 52, 55, 57, 60, 62, 81, 87], 1]
oh_votes_sanders_b10 = oh.iloc[[9, 33, 34, 52, 55, 57, 60, 62, 81, 87], 2]
ten_low_pop_county = oh.iloc[[9, 33, 34, 52, 55, 57, 60, 62, 81, 87], 0]

# create plot
fig, ax = plt.subplots(figsize=(20,12))
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, oh_votes_clinton_b10, bar_width,
                                        alpha=opacity,
                                        color='b',
                                        label='Clinton')

rects2 = plt.bar(index + bar_width, oh_votes_sanders_b10, bar_width,
                                                    alpha=opacity,
                                                    color='g',
                                                    label='Sanders')

plt.xlabel('Counties', fontsize=25)
plt.ylabel('Vote Total', fontsize=25)
plt.title('2016 Ohio Democratic Primary Results', fontsize=20)
plt.xticks(index + bar_width, az['County'], fontsize=20)
plt.yticks(fontsize=15)
plt.legend(fontsize=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Let's Look At Primary Polls

# %%
primary_polls = pd.read_csv('../Data/dem_primary_polls.csv')
primary_polls.head()
primary_polls['start_date'] = primary_polls['start_date'].astype('datetime64[ns]')
primary_polls['end_date'] = primary_polls['end_date'].astype('datetime64[ns]')

# %%
ariz = primary_polls[primary_polls['state']=='Arizona']
ohio = primary_polls[primary_polls['state']=='Ohio']
florida = primary_polls[primary_polls['state']=='Florida']
illinois = primary_polls[primary_polls['state']=='Illinois']

# %%
sanders_ariz = ariz[ariz['answer']=='Sanders']
sanders_ariz.set_index(['start_date'], inplace=True)

sanders_ohio = ohio[ohio['answer']=='Sanders']
sanders_ohio.set_index(['start_date'], inplace=True)

sanders_florida = florida[florida['answer']=='Sanders']
sanders_florida.set_index(['start_date'], inplace=True)

sanders_illinois = illinois[illinois['answer']=='Sanders']
sanders_illinois.set_index(['start_date'], inplace=True)

biden_arizona = ariz[ariz['answer']=='Biden']
biden_arizona.set_index(['start_date'], inplace=True)

biden_ohio = ohio[ohio['answer']=='Biden']
biden_ohio.set_index(['start_date'], inplace=True)

biden_florida = florida[florida['answer']=='Biden']
biden_florida.set_index(['start_date'], inplace=True)

biden_illinois = illinois[illinois['answer']=="Biden"]
biden_illinois.set_index(['start_date'], inplace=True)

# %%
style.use('fivethirtyeight')
plt.title('Ohio')
plt.plot(biden_ohio.index.values, biden_ohio['pct'], label='Biden')
plt.plot(sanders_ohio.index.values, sanders_ohio['pct'], label='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Florida')
plt.plot(biden_florida.index.values, biden_florida['pct'], label='Biden')
plt.plot(sanders_florida.index.values, sanders_florida['pct'], label='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Arizona')
plt.plot(biden_arizona.index.values, biden_arizona['pct'], label='Biden')
plt.plot(sanders_ariz.index.values, sanders_ariz['pct'], label='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %%
style.use('fivethirtyeight')
plt.title('Illinois')
plt.plot(biden_illinois.index.values, biden_illinois['pct'], label='Biden')
plt.plot(sanders_illinois.index.values, sanders_illinois['pct'], label='Sanders')
plt.legend();
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Since last meeting I have decided to take a different approach and that'll be to conduct bayesian inference on participation rates in 2016 Demcratic primary election.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pymc3 as pm
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
df = pd.read_csv('../Data/18-29.csv')

# %%
cols = ['18-29_2020', '18-29_2016']
y = pd.DataFrame(imp.fit_transform(df[cols]), columns = cols)
y['State'] = df['State'].copy()

# %%
y
# Out:
#     18-29_2020  18-29_2016           State
# 0         0.15    0.200000           Texas
# 1         0.10    0.164286       Colorado
# 2         0.19    0.164286       Minnesota
# 3         0.16    0.190000        Michigan
# 4         0.13    0.160000       Virginia
# 5         0.16    0.164286   Massachusetts
# 6         0.15    0.164286           Maine
# 7         0.14    0.180000  North Carolina
# 8         0.11    0.150000  South Carolina
# 9         0.14    0.160000        Missouri
# 10        0.11    0.150000        Tennesse
# 11        0.13    0.150000     Mississippi
# 12        0.10    0.120000        Oklahoma
# 13        0.11    0.150000         Vermont
# 14        0.13    0.190000   New Hampshire
# 15        0.10    0.140000         Alabama
# 16        0.24    0.180000            Iowa
# 17        0.17    0.180000          Nevada

# %%
with pm.Model() as model:
    # Set priors for parameters
    beta_0 = pm.Normal('beta_0', mu=0, sd=5)
    beta_1 = pm.Normal('beta_1', mu=1, sd=0.2)
    sigma = pm.Uniform('sigma', lower=0, upper=8)
    Y_obs = pm.Normal(
        'Y_obs',
        mu = beta_0 + beta_1*y['18-29_2016'],
        sd = sigma,
        observed = y['18-29_2020']
    )
    trace = pm.sample(10000, tune=1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, beta_1, beta_0]
# Sampling 2 chains, 1 divergences: 100%|██████████| 22000/22000 [00:36<00:00, 597.82draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace);
# Out:
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"

# %%
df_2 = pd.read_csv('../Data/30-44.csv')

# %%
df_2.head()
# Out:
#        State  30-44_2020  30-44_2016
# 0      Texas        0.15        0.20
# 1  Colorado         0.10         NaN
# 2  Minnesota        0.19         NaN
# 3   Michigan        0.16        0.19
# 4  Virginia         0.13        0.16

# %%
cols = ['30-44_2020', '30-44_2016']
y_2 = pd.DataFrame(imp.fit_transform(df_2[cols]), columns = cols)
y_2['State'] = df_2['State'].copy()

# %%
y_2
# Out:
#     30-44_2020  30-44_2016           State
# 0         0.15    0.200000           Texas
# 1         0.10    0.164286       Colorado
# 2         0.19    0.164286       Minnesota
# 3         0.16    0.190000        Michigan
# 4         0.13    0.160000       Virginia
# 5         0.16    0.164286   Massachusetts
# 6         0.15    0.164286           Maine
# 7         0.14    0.180000  North Carolina
# 8         0.11    0.150000  South Carolina
# 9         0.14    0.160000        Missouri
# 10        0.11    0.150000        Tennesse
# 11        0.13    0.150000     Mississippi
# 12        0.10    0.120000        Oklahoma
# 13        0.11    0.150000         Vermont
# 14        0.13    0.190000   New Hampshire
# 15        0.10    0.140000         Alabama
# 16        0.24    0.180000            Iowa
# 17        0.17    0.180000          Nevada

# %%
with pm.Model() as model_2:
    # Set priors for parameters
    beta_0 = pm.Normal('beta_0', mu=0, sd=5)
    beta_1 = pm.Normal('beta_1', mu=1, sd=0.2)
    sigma = pm.Uniform('sigma', lower=0, upper=8)
    Y_obs = pm.Normal(
        'Y_obs',
        mu = beta_0 + beta_1*y_2['30-44_2016'],
        sd = sigma,
        observed = y_2['30-44_2020']
    )
    trace_2 = pm.sample(10000, tune=1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, beta_1, beta_0]
# Sampling 2 chains, 4 divergences: 100%|██████████| 22000/22000 [00:33<00:00, 651.49draws/s]
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace_2);
# Out:
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"

# %%
df_3 = pd.read_csv('../Data/45_64.csv')
df_3
# Out:
#              State  45-64_2020  45-64_2016
# 0            Texas        0.38        0.40
# 1        Colorado         0.33         NaN
# 2        Minnesota        0.32         NaN
# 3         Michigan        0.42        0.35
# 4        Virginia         0.40        0.37
# 5    Massachusetts        0.36         NaN
# 6            Maine        0.33         NaN
# 7   North Carolina        0.37        0.42
# 8   South Carolina        0.42        0.47
# 9         Missouri        0.36        0.37
# 10        Tennesse        0.40        0.43
# 11     Mississippi        0.42        0.40
# 12        Oklahoma        0.32        0.39
# 13         Vermont        0.41        0.41
# 14   New Hampshire        0.39        0.42
# 15         Alabama        0.38        0.39
# 16            Iowa        0.28        0.36
# 17          Nevada        0.35        0.35

# %%
cols = ['45-64_2020', '45-64_2016']
y_3 = pd.DataFrame(imp.fit_transform(df_3[cols]), columns = cols)
y_3['State'] = df_3['State'].copy()

# %%
with pm.Model() as model_3:
    # Set priors for parameters
    beta_0 = pm.Normal('beta_0', mu=0, sd=5)
    beta_1 = pm.Normal('beta_1', mu=1, sd=0.2)
    sigma = pm.Uniform('sigma', lower=0, upper=8)
    Y_obs = pm.Normal(
        'Y_obs',
        mu = beta_0 + beta_1*y_3['45-64_2016'],
        sd = sigma,
        observed = y_3['45-64_2020']
    )
    trace_3 = pm.sample(10000, tune=1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, beta_1, beta_0]
# Sampling 2 chains, 3 divergences: 100%|██████████| 22000/22000 [00:54<00:00, 403.02draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace_3);
# Out:
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/danielleo/opt/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"

# %%
pm.summary(trace).round(3)
# Out:
#          mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# beta_0 -0.025  0.031  -0.084    0.031      0.000    0.000    6150.0  5710.0
# beta_1  1.008  0.181   0.674    1.351      0.002    0.002    6114.0  6102.0
# sigma   0.033  0.006   0.022    0.044      0.000    0.000    8024.0  7580.0
#
#         ess_bulk  ess_tail  r_hat
# beta_0    6162.0    7019.0    1.0
# beta_1    6121.0    6921.0    1.0
# sigma     8646.0    8491.0    1.0

# %%
pm.summary(trace_2).round(3)
# Out:
#          mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# beta_0  0.024  0.070  -0.108    0.153      0.001    0.001    5999.0  5406.0
# beta_1  0.872  0.177   0.561    1.220      0.002    0.002    6000.0  6000.0
# sigma   0.043  0.009   0.028    0.059      0.000    0.000    5215.0  5151.0
#
#         ess_bulk  ess_tail  r_hat
# beta_0    5982.0    6422.0    1.0
# beta_1    5983.0    6390.0    1.0
# sigma     4836.0    3579.0    1.0

# %%
pm.summary(trace_3).round(3)
# Out:
#          mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# beta_0  0.023  0.070  -0.105    0.157      0.001    0.001    6314.0  5847.0
# beta_1  0.877  0.175   0.543    1.199      0.002    0.002    6316.0  6226.0
# sigma   0.043  0.008   0.029    0.058      0.000    0.000    6678.0  6376.0
#
#         ess_bulk  ess_tail  r_hat
# beta_0    6322.0    7664.0    1.0
# beta_1    6320.0    7580.0    1.0
# sigma     7080.0    7274.0    1.0

# %% [markdown]
# # Conclusion and Next Steps

# %% [markdown]
# So obviously I do not have a good grip on bayesian inference and MCMC methods for creating posterior distributions. However, I believe this method conducted does warrant some logical sense. Going forward I need to reconsider what kind of prior distributions I am using for a problem such as predicting voter turnout.
#
# I dove into the literature about different distributions but never felt comfortable coming up with a different proposed distribution and will coontinue to examine posibilities in terms of that part of my capstone project.
